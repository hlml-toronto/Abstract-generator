# %%
# %matplotlib inline

# %% [markdown]
# [link text](https://)
# Sequence-to-Sequence Modeling with nn.Transformer and TorchText
# ===============================================================
#
# This is a tutorial on how to train a sequence-to-sequence model
# that uses the
# `nn.Transformer <https://pytorch.org/docs/master/nn.html?highlight=nn%20transformer#torch.nn.Transformer>`__ module.
#
# PyTorch 1.2 release includes a standard transformer module based on the
# paper `Attention is All You
# Need <https://arxiv.org/pdf/1706.03762.pdf>`__. The transformer model
# has been proved to be superior in quality for many sequence-to-sequence
# problems while being more parallelizable. The ``nn.Transformer`` module
# relies entirely on an attention mechanism (another module recently
# implemented as `nn.MultiheadAttention <https://pytorch.org/docs/master/nn.html?highlight=multiheadattention#torch.nn.MultiheadAttention>`__) to draw global dependencies
# between input and output. The ``nn.Transformer`` module is now highly
# modularized such that a single component (like `nn.TransformerEncoder <https://pytorch.org/docs/master/nn.html?highlight=nn%20transformerencoder#torch.nn.TransformerEncoder>`__
# in this tutorial) can be easily adapted/composed.
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_downloads/_static/img/transformer_architecture.jpg?raw=1)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Define the model
# ----------------

# %% [markdown]
# In this tutorial, we train ``nn.TransformerEncoder`` model on a
# language modeling task. The language modeling task is to assign a
# probability for the likelihood of a given word (or a sequence of words)
# to follow a sequence of words. A sequence of tokens are passed to the embedding
# layer first, followed by a positional encoding layer to account for the order
# of the word (see the next paragraph for more details). The
# ``nn.TransformerEncoder`` consists of multiple layers of
# `nn.TransformerEncoderLayer <https://pytorch.org/docs/master/nn.html?highlight=transformerencoderlayer#torch.nn.TransformerEncoderLayer>`__. Along with the input sequence, a square
# attention mask is required because the self-attention layers in
# ``nn.TransformerEncoder`` are only allowed to attend the earlier positions in
# the sequence. For the language modeling task, any tokens on the future
# positions should be masked. To have the actual words, the output
# of ``nn.TransformerEncoder`` model is sent to the final Linear
# layer, which is followed by a log-Softmax function.

# %%
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer

class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src, src_mask):
        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, src_mask)
        output = self.decoder(output)
        return output

# %% [markdown]
# ``PositionalEncoding`` module injects some information about the
# relative or absolute position of the tokens in the sequence. The
# positional encodings have the same dimension as the embeddings so that
# the two can be summed. Here, we use ``sine`` and ``cosine`` functions of
# different frequencies.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %% [markdown]
# Load and batch data
# -------------------

# %% [markdown]
# This tutorial uses ``torchtext`` to generate Wikitext-2 dataset. The
# vocab object is built based on the train dataset and is used to numericalize
# tokens into tensors. Starting from sequential data, the ``batchify()``
# function arranges the dataset into columns, trimming off any tokens remaining
# after the data has been divided into batches of size ``batch_size``.
# For instance, with the alphabet as the sequence (total length of 26)
# and a batch size of 4, we would divide the alphabet into 4 sequences of
# length 6:
#
# \begin{align}\begin{bmatrix}
#   \text{A} & \text{B} & \text{C} & \ldots & \text{X} & \text{Y} & \text{Z}
#   \end{bmatrix}
#   \Rightarrow
#   \begin{bmatrix}
#   \begin{bmatrix}\text{A} \\ \text{B} \\ \text{C} \\ \text{D} \\ \text{E} \\ \text{F}\end{bmatrix} &
#   \begin{bmatrix}\text{G} \\ \text{H} \\ \text{I} \\ \text{J} \\ \text{K} \\ \text{L}\end{bmatrix} &
#   \begin{bmatrix}\text{M} \\ \text{N} \\ \text{O} \\ \text{P} \\ \text{Q} \\ \text{R}\end{bmatrix} &
#   \begin{bmatrix}\text{S} \\ \text{T} \\ \text{U} \\ \text{V} \\ \text{W} \\ \text{X}\end{bmatrix}
#   \end{bmatrix}\end{align}
#
# These columns are treated as independent by the model, which means that
# the dependence of ``G`` and ``F`` can not be learned, but allows more
# efficient batch processing.

# %%
import io
import torch
from torchtext.datasets import WikiText2
from torchtext.data.utils import get_tokenizer
from collections import Counter
from torchtext.vocab import Vocab

train_iter = WikiText2(split='train')
tokenizer = get_tokenizer('basic_english')
counter = Counter()
for line in train_iter:
    counter.update(tokenizer(line))
vocab = Vocab(counter)

def data_process(raw_text_iter):
  data = [torch.tensor([vocab[token] for token in tokenizer(item)],
                       dtype=torch.long) for item in raw_text_iter]
  return torch.cat(tuple(filter(lambda t: t.numel() > 0, data)))

train_iter, val_iter, test_iter = WikiText2()
train_data = data_process(train_iter)
val_data = data_process(val_iter)
test_data = data_process(test_iter)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def batchify(data, bsz):
    # Divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 3
eval_batch_size = 3
train_data = batchify(train_data, batch_size)
val_data = batchify(val_data, eval_batch_size)
test_data = batchify(test_data, eval_batch_size)
# Out:
# wikitext-2-v1.zip: 100%|██████████| 4.48M/4.48M [00:00<00:00, 10.3MB/s]

# %%
print(torch.cuda.is_available())
print(device)
# Out:
# True
# cuda

# %% [markdown]
# ``get_batch()`` function generates the input and target sequence for
# the transformer model. It subdivides the source data into chunks of
# length ``bptt``. For the language modeling task, the model needs the
# following words as ``Target``. For example, with a ``bptt`` value of 2,
# we’d get the following two Variables for ``i`` = 0:
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_downloads/_static/img/transformer_input_target.png?raw=1)
#
#
# It should be noted that the chunks are along dimension 0, consistent
# with the ``S`` dimension in the Transformer model. The batch dimension
# ``N`` is along dimension 1.

# %%
bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].reshape(-1)
    return data, target

def get_batch_alt(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target_alt = source[i+1:i+1+seq_len]
    return data, target_alt

# %% [markdown]
# Initiate an instance
# --------------------

# %% [markdown]
# The model is set up with the hyperparameter below. The vocab size is
# equal to the length of the vocab object.

# %%
ntokens = len(vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %% [markdown]
# Run the model
# -------------

# %% [markdown]
# `CrossEntropyLoss <https://pytorch.org/docs/master/nn.html?highlight=crossentropyloss#torch.nn.CrossEntropyLoss>`__
# is applied to track the loss and
# `SGD <https://pytorch.org/docs/master/optim.html?highlight=sgd#torch.optim.SGD>`__
# implements stochastic gradient descent method as the optimizer. The initial
# learning rate is set to 5.0. `StepLR <https://pytorch.org/docs/master/optim.html?highlight=steplr#torch.optim.lr_scheduler.StepLR>`__ is
# applied to adjust the learn rate through epochs. During the
# training, we use
# `nn.utils.clip_grad_norm\_ <https://pytorch.org/docs/master/nn.html?highlight=nn%20utils%20clip_grad_norm#torch.nn.utils.clip_grad_norm_>`__
# function to scale all the gradient together to prevent exploding.

# %%
import time

criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

def train():
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    src_mask = model.generate_square_subsequent_mask(bptt).to(device)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        if data.size(0) != bptt:
            src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
        output = model(data, src_mask)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_last_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    src_mask = model.generate_square_subsequent_mask(bptt).to(device)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            if data.size(0) != bptt:
                src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
            output = eval_model(data, src_mask)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %% [markdown]
# Loop over epochs. Save the model if the validation loss is the best
# we've seen so far. Adjust the learning rate after each epoch.

# %%
best_val_loss = float("inf")
epochs = 100  # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, val_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch  51 |   200/19523 batches | lr 0.38 | ms/batch  6.74 | loss  5.04 | ppl   153.79
# | epoch  51 |   400/19523 batches | lr 0.38 | ms/batch  6.75 | loss  5.02 | ppl   151.32
# | epoch  51 |   600/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.01 | ppl   149.16
# | epoch  51 |   800/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.99 | ppl   146.58
# | epoch  51 |  1000/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.92 | ppl   137.26
# | epoch  51 |  1200/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.93 | ppl   138.51
# | epoch  51 |  1400/19523 batches | lr 0.38 | ms/batch  6.75 | loss  5.03 | ppl   152.27
# | epoch  51 |  1600/19523 batches | lr 0.38 | ms/batch  6.69 | loss  4.97 | ppl   144.31
# | epoch  51 |  1800/19523 batches | lr 0.38 | ms/batch  6.76 | loss  4.90 | ppl   134.84
# | epoch  51 |  2000/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.95 | ppl   141.26
# | epoch  51 |  2200/19523 batches | lr 0.38 | ms/batch  6.72 | loss  5.01 | ppl   149.28
# | epoch  51 |  2400/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.96 | ppl   142.22
# | epoch  51 |  2600/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.71 | ppl   110.54
# | epoch  51 |  2800/19523 batches | lr 0.38 | ms/batch  6.68 | loss  5.03 | ppl   153.14
# | epoch  51 |  3000/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.85 | ppl   128.04
# | epoch  51 |  3200/19523 batches | lr 0.38 | ms/batch  6.69 | loss  4.98 | ppl   146.18
# | epoch  51 |  3400/19523 batches | lr 0.38 | ms/batch  6.73 | loss  4.95 | ppl   140.96
# | epoch  51 |  3600/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.99 | ppl   146.44
# | epoch  51 |  3800/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.93 | ppl   138.83
# | epoch  51 |  4000/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.93 | ppl   138.54
# | epoch  51 |  4200/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.93 | ppl   137.82
# | epoch  51 |  4400/19523 batches | lr 0.38 | ms/batch  6.71 | loss  4.81 | ppl   122.27
# | epoch  51 |  4600/19523 batches | lr 0.38 | ms/batch  6.64 | loss  5.04 | ppl   154.01
# | epoch  51 |  4800/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.78 | ppl   119.29
# | epoch  51 |  5000/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.09 | ppl   162.96
# | epoch  51 |  5200/19523 batches | lr 0.38 | ms/batch  6.64 | loss  4.94 | ppl   140.47
# | epoch  51 |  5400/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.90 | ppl   133.84
# | epoch  51 |  5600/19523 batches | lr 0.38 | ms/batch  6.73 | loss  4.99 | ppl   146.44
# | epoch  51 |  5800/19523 batches | lr 0.38 | ms/batch  6.61 | loss  4.92 | ppl   137.05
# | epoch  51 |  6000/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.92 | ppl   136.34
# | epoch  51 |  6200/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.12 | ppl   166.89
# | epoch  51 |  6400/19523 batches | lr 0.38 | ms/batch  6.82 | loss  4.90 | ppl   133.92
# | epoch  51 |  6600/19523 batches | lr 0.38 | ms/batch  6.70 | loss  4.91 | ppl   136.24
# | epoch  51 |  6800/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.01 | ppl   149.99
# | epoch  51 |  7000/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.98 | ppl   145.07
# | epoch  51 |  7200/19523 batches | lr 0.38 | ms/batch  6.68 | loss  5.00 | ppl   148.98
# | epoch  51 |  7400/19523 batches | lr 0.38 | ms/batch  6.65 | loss  5.01 | ppl   150.43
# | epoch  51 |  7600/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.88 | ppl   131.40
# | epoch  51 |  7800/19523 batches | lr 0.38 | ms/batch  6.79 | loss  4.95 | ppl   140.87
# | epoch  51 |  8000/19523 batches | lr 0.38 | ms/batch  6.79 | loss  5.04 | ppl   154.31
# | epoch  51 |  8200/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.90 | ppl   133.99
# | epoch  51 |  8400/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.89 | ppl   132.67
# | epoch  51 |  8600/19523 batches | lr 0.38 | ms/batch  6.70 | loss  4.70 | ppl   109.67
# | epoch  51 |  8800/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.04 | ppl   154.24
# | epoch  51 |  9000/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.91 | ppl   135.38
# | epoch  51 |  9200/19523 batches | lr 0.38 | ms/batch  6.62 | loss  5.06 | ppl   156.81
# | epoch  51 |  9400/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.07 | ppl   159.73
# | epoch  51 |  9600/19523 batches | lr 0.38 | ms/batch  6.67 | loss  5.05 | ppl   155.64
# | epoch  51 |  9800/19523 batches | lr 0.38 | ms/batch  6.79 | loss  5.07 | ppl   159.90
# | epoch  51 | 10000/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.89 | ppl   133.62
# | epoch  51 | 10200/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.99 | ppl   147.12
# | epoch  51 | 10400/19523 batches | lr 0.38 | ms/batch  6.75 | loss  4.99 | ppl   147.52
# | epoch  51 | 10600/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.86 | ppl   129.00
# | epoch  51 | 10800/19523 batches | lr 0.38 | ms/batch  6.69 | loss  4.90 | ppl   134.74
# | epoch  51 | 11000/19523 batches | lr 0.38 | ms/batch  6.77 | loss  4.99 | ppl   147.32
# | epoch  51 | 11200/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.04 | ppl   154.45
# | epoch  51 | 11400/19523 batches | lr 0.38 | ms/batch  6.74 | loss  4.96 | ppl   143.31
# | epoch  51 | 11600/19523 batches | lr 0.38 | ms/batch  6.67 | loss  5.04 | ppl   153.98
# | epoch  51 | 11800/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.80 | ppl   122.07
# | epoch  51 | 12000/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.84 | ppl   126.75
# | epoch  51 | 12200/19523 batches | lr 0.38 | ms/batch  6.79 | loss  4.97 | ppl   144.68
# | epoch  51 | 12400/19523 batches | lr 0.38 | ms/batch  6.70 | loss  4.96 | ppl   142.99
# | epoch  51 | 12600/19523 batches | lr 0.38 | ms/batch  6.68 | loss  5.12 | ppl   166.54
# | epoch  51 | 12800/19523 batches | lr 0.38 | ms/batch  6.65 | loss  5.01 | ppl   149.85
# | epoch  51 | 13000/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.97 | ppl   143.73
# | epoch  51 | 13200/19523 batches | lr 0.38 | ms/batch  6.72 | loss  5.01 | ppl   150.17
# | epoch  51 | 13400/19523 batches | lr 0.38 | ms/batch  6.66 | loss  5.02 | ppl   150.98
# | epoch  51 | 13600/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.93 | ppl   138.71
# | epoch  51 | 13800/19523 batches | lr 0.38 | ms/batch  6.73 | loss  4.93 | ppl   137.97
# | epoch  51 | 14000/19523 batches | lr 0.38 | ms/batch  6.77 | loss  4.90 | ppl   133.86
# | epoch  51 | 14200/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.94 | ppl   139.98
# | epoch  51 | 14400/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.99 | ppl   147.60
# | epoch  51 | 14600/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.87 | ppl   129.72
# | epoch  51 | 14800/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.85 | ppl   127.34
# | epoch  51 | 15000/19523 batches | lr 0.38 | ms/batch  6.63 | loss  4.88 | ppl   131.04
# | epoch  51 | 15200/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.92 | ppl   136.88
# | epoch  51 | 15400/19523 batches | lr 0.38 | ms/batch  6.87 | loss  4.81 | ppl   123.13
# | epoch  51 | 15600/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.91 | ppl   135.39
# | epoch  51 | 15800/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.91 | ppl   135.47
# | epoch  51 | 16000/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.98 | ppl   145.75
# | epoch  51 | 16200/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.92 | ppl   137.35
# | epoch  51 | 16400/19523 batches | lr 0.38 | ms/batch  6.72 | loss  4.82 | ppl   124.19
# | epoch  51 | 16600/19523 batches | lr 0.38 | ms/batch  6.66 | loss  4.97 | ppl   144.72
# | epoch  51 | 16800/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.79 | ppl   120.69
# | epoch  51 | 17000/19523 batches | lr 0.38 | ms/batch  6.73 | loss  5.11 | ppl   165.16
# | epoch  51 | 17200/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.88 | ppl   132.29
# | epoch  51 | 17400/19523 batches | lr 0.38 | ms/batch  6.70 | loss  5.00 | ppl   148.45
# | epoch  51 | 17600/19523 batches | lr 0.38 | ms/batch  6.63 | loss  4.84 | ppl   126.75
# | epoch  51 | 17800/19523 batches | lr 0.38 | ms/batch  6.68 | loss  5.08 | ppl   161.51
# | epoch  51 | 18000/19523 batches | lr 0.38 | ms/batch  6.71 | loss  4.92 | ppl   137.20
# | epoch  51 | 18200/19523 batches | lr 0.38 | ms/batch  6.67 | loss  5.01 | ppl   150.46
# | epoch  51 | 18400/19523 batches | lr 0.38 | ms/batch  6.69 | loss  5.03 | ppl   153.37
# | epoch  51 | 18600/19523 batches | lr 0.38 | ms/batch  6.73 | loss  4.94 | ppl   140.38
# | epoch  51 | 18800/19523 batches | lr 0.38 | ms/batch  6.65 | loss  4.85 | ppl   127.69
# | epoch  51 | 19000/19523 batches | lr 0.38 | ms/batch  6.67 | loss  4.99 | ppl   146.63
# | epoch  51 | 19200/19523 batches | lr 0.38 | ms/batch  6.68 | loss  4.88 | ppl   132.11
# | epoch  51 | 19400/19523 batches | lr 0.38 | ms/batch  6.63 | loss  4.91 | ppl   135.01
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 134.57s | valid loss  5.85 | valid ppl   348.58
# -----------------------------------------------------------------------------------------
# | epoch  52 |   200/19523 batches | lr 0.37 | ms/batch  6.72 | loss  5.04 | ppl   155.17
# | epoch  52 |   400/19523 batches | lr 0.37 | ms/batch  6.69 | loss  5.03 | ppl   152.29
# | epoch  52 |   600/19523 batches | lr 0.37 | ms/batch  6.69 | loss  4.99 | ppl   147.52
# | epoch  52 |   800/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.98 | ppl   145.65
# | epoch  52 |  1000/19523 batches | lr 0.37 | ms/batch  6.64 | loss  4.92 | ppl   137.59
# | epoch  52 |  1200/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.93 | ppl   138.86
# | epoch  52 |  1400/19523 batches | lr 0.37 | ms/batch  6.70 | loss  5.04 | ppl   154.11
# | epoch  52 |  1600/19523 batches | lr 0.37 | ms/batch  6.72 | loss  4.99 | ppl   146.65
# | epoch  52 |  1800/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.91 | ppl   135.66
# | epoch  52 |  2000/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.96 | ppl   142.21
# | epoch  52 |  2200/19523 batches | lr 0.37 | ms/batch  6.69 | loss  5.02 | ppl   150.67
# | epoch  52 |  2400/19523 batches | lr 0.37 | ms/batch  6.72 | loss  4.97 | ppl   143.52
# | epoch  52 |  2600/19523 batches | lr 0.37 | ms/batch  6.69 | loss  4.71 | ppl   110.93
# | epoch  52 |  2800/19523 batches | lr 0.37 | ms/batch  6.76 | loss  5.04 | ppl   154.00
# | epoch  52 |  3000/19523 batches | lr 0.37 | ms/batch  6.63 | loss  4.85 | ppl   128.03
# | epoch  52 |  3200/19523 batches | lr 0.37 | ms/batch  6.62 | loss  4.99 | ppl   147.09
# | epoch  52 |  3400/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.95 | ppl   140.49
# | epoch  52 |  9800/19523 batches | lr 0.37 | ms/batch  6.65 | loss  5.08 | ppl   160.80
# | epoch  52 | 10000/19523 batches | lr 0.37 | ms/batch  6.75 | loss  4.89 | ppl   133.38
# | epoch  52 | 10200/19523 batches | lr 0.37 | ms/batch  6.65 | loss  4.99 | ppl   147.39
# | epoch  52 | 10400/19523 batches | lr 0.37 | ms/batch  6.65 | loss  4.99 | ppl   147.59
# | epoch  52 | 10600/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.87 | ppl   130.74
# | epoch  52 | 10800/19523 batches | lr 0.37 | ms/batch  6.64 | loss  4.91 | ppl   136.14
# | epoch  52 | 11000/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.99 | ppl   146.22
# | epoch  52 | 11200/19523 batches | lr 0.37 | ms/batch  6.78 | loss  5.04 | ppl   154.10
# | epoch  52 | 11400/19523 batches | lr 0.37 | ms/batch  6.69 | loss  4.96 | ppl   143.21
# | epoch  52 | 11600/19523 batches | lr 0.37 | ms/batch  6.64 | loss  5.03 | ppl   152.63
# | epoch  52 | 11800/19523 batches | lr 0.37 | ms/batch  6.81 | loss  4.81 | ppl   122.18
# | epoch  52 | 12000/19523 batches | lr 0.37 | ms/batch  6.68 | loss  4.85 | ppl   127.74
# | epoch  52 | 12200/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.98 | ppl   145.17
# | epoch  52 | 12400/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.96 | ppl   142.81
# | epoch  52 | 12600/19523 batches | lr 0.37 | ms/batch  6.63 | loss  5.12 | ppl   167.66
# | epoch  52 | 12800/19523 batches | lr 0.37 | ms/batch  6.67 | loss  5.02 | ppl   151.55
# | epoch  52 | 13000/19523 batches | lr 0.37 | ms/batch  6.72 | loss  4.98 | ppl   145.54
# | epoch  52 | 13200/19523 batches | lr 0.37 | ms/batch  6.76 | loss  5.02 | ppl   151.43
# | epoch  52 | 13400/19523 batches | lr 0.37 | ms/batch  6.73 | loss  5.01 | ppl   150.59
# | epoch  52 | 13600/19523 batches | lr 0.37 | ms/batch  6.68 | loss  4.93 | ppl   138.68
# | epoch  52 | 13800/19523 batches | lr 0.37 | ms/batch  6.78 | loss  4.93 | ppl   138.86
# | epoch  52 | 14000/19523 batches | lr 0.37 | ms/batch  6.68 | loss  4.90 | ppl   134.90
# | epoch  52 | 14200/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.93 | ppl   139.04
# | epoch  52 | 14400/19523 batches | lr 0.37 | ms/batch  6.71 | loss  5.00 | ppl   148.18
# | epoch  52 | 14600/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.86 | ppl   129.09
# | epoch  52 | 14800/19523 batches | lr 0.37 | ms/batch  6.66 | loss  4.84 | ppl   126.27
# | epoch  52 | 15000/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.87 | ppl   130.75
# | epoch  52 | 15200/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.92 | ppl   136.80
# | epoch  52 | 15400/19523 batches | lr 0.37 | ms/batch  6.63 | loss  4.80 | ppl   121.88
# | epoch  52 | 15600/19523 batches | lr 0.37 | ms/batch  6.65 | loss  4.91 | ppl   135.29
# | epoch  52 | 15800/19523 batches | lr 0.37 | ms/batch  6.68 | loss  4.90 | ppl   134.80
# | epoch  52 | 16000/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.98 | ppl   146.20
# | epoch  52 | 16200/19523 batches | lr 0.37 | ms/batch  6.70 | loss  4.92 | ppl   137.34
# | epoch  52 | 16400/19523 batches | lr 0.37 | ms/batch  6.66 | loss  4.82 | ppl   124.15
# | epoch  52 | 16600/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.97 | ppl   144.40
# | epoch  52 | 16800/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.79 | ppl   120.12
# | epoch  52 | 17000/19523 batches | lr 0.37 | ms/batch  6.67 | loss  5.10 | ppl   164.43
# | epoch  52 | 17200/19523 batches | lr 0.37 | ms/batch  6.68 | loss  4.89 | ppl   132.39
# | epoch  52 | 17400/19523 batches | lr 0.37 | ms/batch  6.70 | loss  5.01 | ppl   150.49
# | epoch  52 | 17600/19523 batches | lr 0.37 | ms/batch  6.69 | loss  4.84 | ppl   126.98
# | epoch  52 | 17800/19523 batches | lr 0.37 | ms/batch  6.73 | loss  5.09 | ppl   162.18
# | epoch  52 | 18000/19523 batches | lr 0.37 | ms/batch  6.69 | loss  4.91 | ppl   135.71
# | epoch  52 | 18200/19523 batches | lr 0.37 | ms/batch  6.70 | loss  5.02 | ppl   150.84
# | epoch  52 | 18400/19523 batches | lr 0.37 | ms/batch  6.67 | loss  5.03 | ppl   152.93
# | epoch  52 | 18600/19523 batches | lr 0.37 | ms/batch  6.71 | loss  4.94 | ppl   139.88
# | epoch  52 | 18800/19523 batches | lr 0.37 | ms/batch  6.72 | loss  4.85 | ppl   127.60
# | epoch  52 | 19000/19523 batches | lr 0.37 | ms/batch  6.67 | loss  4.97 | ppl   144.62
# | epoch  52 | 19200/19523 batches | lr 0.37 | ms/batch  6.73 | loss  4.89 | ppl   132.70
# | epoch  52 | 19400/19523 batches | lr 0.37 | ms/batch  6.74 | loss  4.90 | ppl   134.93
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 134.54s | valid loss  5.84 | valid ppl   343.63
# -----------------------------------------------------------------------------------------
# | epoch  53 |   200/19523 batches | lr 0.35 | ms/batch  6.72 | loss  5.05 | ppl   155.73
# | epoch  53 |   400/19523 batches | lr 0.35 | ms/batch  6.66 | loss  5.03 | ppl   153.53
# | epoch  53 |   600/19523 batches | lr 0.35 | ms/batch  6.66 | loss  5.00 | ppl   148.39
# | epoch  53 |   800/19523 batches | lr 0.35 | ms/batch  6.81 | loss  4.98 | ppl   145.95
# | epoch  53 |  1000/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.92 | ppl   137.29
# | epoch  53 |  1200/19523 batches | lr 0.35 | ms/batch  6.67 | loss  4.93 | ppl   138.55
# | epoch  53 |  1400/19523 batches | lr 0.35 | ms/batch  6.73 | loss  5.04 | ppl   154.72
# | epoch  53 |  1600/19523 batches | lr 0.35 | ms/batch  6.64 | loss  4.99 | ppl   147.06
# | epoch  53 |  1800/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.91 | ppl   136.01
# | epoch  53 |  2000/19523 batches | lr 0.35 | ms/batch  6.74 | loss  4.95 | ppl   141.34
# | epoch  53 |  2200/19523 batches | lr 0.35 | ms/batch  6.68 | loss  5.02 | ppl   150.96
# | epoch  53 |  2400/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.97 | ppl   144.08
# | epoch  53 |  2600/19523 batches | lr 0.35 | ms/batch  6.67 | loss  4.72 | ppl   111.73
# | epoch  53 |  2800/19523 batches | lr 0.35 | ms/batch  6.72 | loss  5.03 | ppl   153.54
# | epoch  53 |  3000/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.85 | ppl   127.46
# | epoch  53 |  3200/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.99 | ppl   147.59
# | epoch  53 |  3400/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.95 | ppl   141.40
# | epoch  53 |  3600/19523 batches | lr 0.35 | ms/batch  6.64 | loss  4.99 | ppl   147.48
# | epoch  53 |  3800/19523 batches | lr 0.35 | ms/batch  6.75 | loss  4.95 | ppl   141.36
# | epoch  53 |  4000/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.94 | ppl   139.18
# | epoch  53 |  4200/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.93 | ppl   138.52
# | epoch  53 |  4400/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.81 | ppl   122.67
# | epoch  53 |  4600/19523 batches | lr 0.35 | ms/batch  6.72 | loss  5.04 | ppl   154.35
# | epoch  53 |  4800/19523 batches | lr 0.35 | ms/batch  6.63 | loss  4.79 | ppl   119.85
# | epoch  53 |  5000/19523 batches | lr 0.35 | ms/batch  6.72 | loss  5.10 | ppl   164.64
# | epoch  53 |  5200/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.95 | ppl   140.86
# | epoch  53 |  5400/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.89 | ppl   133.13
# | epoch  53 |  5600/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.99 | ppl   146.48
# | epoch  53 |  5800/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.92 | ppl   137.17
# | epoch  53 |  6000/19523 batches | lr 0.35 | ms/batch  6.73 | loss  4.91 | ppl   136.15
# | epoch  53 |  6200/19523 batches | lr 0.35 | ms/batch  6.70 | loss  5.11 | ppl   166.44
# | epoch  53 |  6400/19523 batches | lr 0.35 | ms/batch  6.71 | loss  4.91 | ppl   135.26
# | epoch  53 |  6600/19523 batches | lr 0.35 | ms/batch  6.71 | loss  4.93 | ppl   138.25
# | epoch  53 |  6800/19523 batches | lr 0.35 | ms/batch  6.72 | loss  5.02 | ppl   151.58
# | epoch  53 |  7000/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.98 | ppl   145.29
# | epoch  53 |  7200/19523 batches | lr 0.35 | ms/batch  6.65 | loss  5.01 | ppl   149.44
# | epoch  53 |  7400/19523 batches | lr 0.35 | ms/batch  6.70 | loss  5.01 | ppl   150.12
# | epoch  53 |  7600/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.88 | ppl   131.47
# | epoch  53 |  7800/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.95 | ppl   141.83
# | epoch  53 |  8000/19523 batches | lr 0.35 | ms/batch  6.73 | loss  5.05 | ppl   156.09
# | epoch  53 |  8200/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.91 | ppl   135.22
# | epoch  53 |  8400/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.89 | ppl   133.29
# | epoch  53 |  8600/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.70 | ppl   109.98
# | epoch  53 |  8800/19523 batches | lr 0.35 | ms/batch  6.65 | loss  5.04 | ppl   154.05
# | epoch  53 |  9000/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.93 | ppl   137.77
# | epoch  53 |  9200/19523 batches | lr 0.35 | ms/batch  6.69 | loss  5.05 | ppl   156.22
# | epoch  53 |  9400/19523 batches | lr 0.35 | ms/batch  6.66 | loss  5.06 | ppl   158.27
# | epoch  53 |  9600/19523 batches | lr 0.35 | ms/batch  6.67 | loss  5.06 | ppl   157.11
# | epoch  53 |  9800/19523 batches | lr 0.35 | ms/batch  6.71 | loss  5.09 | ppl   162.29
# | epoch  53 | 10000/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.90 | ppl   133.66
# | epoch  53 | 10200/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.99 | ppl   147.10
# | epoch  53 | 10400/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.99 | ppl   147.08
# | epoch  53 | 10600/19523 batches | lr 0.35 | ms/batch  6.74 | loss  4.87 | ppl   129.94
# | epoch  53 | 10800/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.92 | ppl   136.44
# | epoch  53 | 11000/19523 batches | lr 0.35 | ms/batch  6.80 | loss  4.99 | ppl   146.44
# | epoch  53 | 11200/19523 batches | lr 0.35 | ms/batch  6.74 | loss  5.06 | ppl   156.85
# | epoch  53 | 11400/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.98 | ppl   145.04
# | epoch  53 | 11600/19523 batches | lr 0.35 | ms/batch  6.75 | loss  5.04 | ppl   153.85
# | epoch  53 | 11800/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.80 | ppl   122.00
# | epoch  53 | 12000/19523 batches | lr 0.35 | ms/batch  6.71 | loss  4.85 | ppl   127.43
# | epoch  53 | 12200/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.98 | ppl   145.84
# | epoch  53 | 12400/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.97 | ppl   144.04
# | epoch  53 | 12600/19523 batches | lr 0.35 | ms/batch  6.69 | loss  5.13 | ppl   168.34
# | epoch  53 | 12800/19523 batches | lr 0.35 | ms/batch  6.67 | loss  5.02 | ppl   151.21
# | epoch  53 | 13000/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.98 | ppl   145.89
# | epoch  53 | 13200/19523 batches | lr 0.35 | ms/batch  6.69 | loss  5.01 | ppl   150.41
# | epoch  53 | 13400/19523 batches | lr 0.35 | ms/batch  6.63 | loss  5.02 | ppl   150.95
# | epoch  53 | 13600/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.93 | ppl   138.48
# | epoch  53 | 13800/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.94 | ppl   139.91
# | epoch  53 | 14000/19523 batches | lr 0.35 | ms/batch  6.73 | loss  4.90 | ppl   134.86
# | epoch  53 | 14200/19523 batches | lr 0.35 | ms/batch  6.71 | loss  4.93 | ppl   139.02
# | epoch  53 | 14400/19523 batches | lr 0.35 | ms/batch  6.71 | loss  5.00 | ppl   148.51
# | epoch  53 | 14600/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.85 | ppl   128.12
# | epoch  53 | 14800/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.84 | ppl   126.45
# | epoch  53 | 15000/19523 batches | lr 0.35 | ms/batch  6.66 | loss  4.88 | ppl   131.76
# | epoch  53 | 15200/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.93 | ppl   138.01
# | epoch  53 | 15400/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.81 | ppl   122.97
# | epoch  53 | 15600/19523 batches | lr 0.35 | ms/batch  6.75 | loss  4.92 | ppl   136.77
# | epoch  53 | 15800/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.90 | ppl   134.56
# | epoch  53 | 16000/19523 batches | lr 0.35 | ms/batch  6.78 | loss  4.99 | ppl   146.45
# | epoch  53 | 16200/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.92 | ppl   137.04
# | epoch  53 | 16400/19523 batches | lr 0.35 | ms/batch  6.70 | loss  4.82 | ppl   124.56
# | epoch  53 | 16600/19523 batches | lr 0.35 | ms/batch  6.65 | loss  4.98 | ppl   144.99
# | epoch  53 | 16800/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.79 | ppl   120.27
# | epoch  53 | 17000/19523 batches | lr 0.35 | ms/batch  6.66 | loss  5.11 | ppl   165.80
# | epoch  53 | 17200/19523 batches | lr 0.35 | ms/batch  6.63 | loss  4.89 | ppl   132.80
# | epoch  53 | 17400/19523 batches | lr 0.35 | ms/batch  6.66 | loss  5.02 | ppl   151.45
# | epoch  53 | 17600/19523 batches | lr 0.35 | ms/batch  6.74 | loss  4.85 | ppl   128.20
# | epoch  53 | 17800/19523 batches | lr 0.35 | ms/batch  6.73 | loss  5.09 | ppl   162.13
# | epoch  53 | 18000/19523 batches | lr 0.35 | ms/batch  6.72 | loss  4.93 | ppl   138.43
# | epoch  53 | 18200/19523 batches | lr 0.35 | ms/batch  6.70 | loss  5.01 | ppl   150.47
# | epoch  53 | 18400/19523 batches | lr 0.35 | ms/batch  6.71 | loss  5.03 | ppl   152.91
# | epoch  53 | 18600/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.95 | ppl   141.78
# | epoch  53 | 18800/19523 batches | lr 0.35 | ms/batch  6.71 | loss  4.85 | ppl   127.66
# | epoch  53 | 19000/19523 batches | lr 0.35 | ms/batch  6.69 | loss  4.98 | ppl   145.90
# | epoch  53 | 19200/19523 batches | lr 0.35 | ms/batch  6.68 | loss  4.90 | ppl   134.56
# | epoch  53 | 19400/19523 batches | lr 0.35 | ms/batch  6.74 | loss  4.91 | ppl   135.97
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 134.65s | valid loss  5.84 | valid ppl   342.81
# -----------------------------------------------------------------------------------------
# | epoch  54 |   200/19523 batches | lr 0.33 | ms/batch  6.74 | loss  5.05 | ppl   155.77
# | epoch  54 |   400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.04 | ppl   153.80
# | epoch  54 |   600/19523 batches | lr 0.33 | ms/batch  6.74 | loss  5.00 | ppl   147.82
# | epoch  54 |   800/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.98 | ppl   145.77
# | epoch  54 |  1000/19523 batches | lr 0.33 | ms/batch  6.73 | loss  4.93 | ppl   138.22
# | epoch  54 |  1200/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.94 | ppl   139.44
# | epoch  54 |  1400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.04 | ppl   155.09
# | epoch  54 |  1600/19523 batches | lr 0.33 | ms/batch  6.75 | loss  4.99 | ppl   146.37
# | epoch  54 |  1800/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.91 | ppl   135.24
# | epoch  54 |  2000/19523 batches | lr 0.33 | ms/batch  6.66 | loss  4.97 | ppl   143.74
# | epoch  54 |  2200/19523 batches | lr 0.33 | ms/batch  6.69 | loss  5.01 | ppl   150.32
# | epoch  54 |  2400/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.96 | ppl   143.15
# | epoch  54 |  2600/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.71 | ppl   111.00
# | epoch  54 |  2800/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.04 | ppl   154.68
# | epoch  54 |  3000/19523 batches | lr 0.33 | ms/batch  6.64 | loss  4.85 | ppl   128.03
# | epoch  54 |  3200/19523 batches | lr 0.33 | ms/batch  6.69 | loss  5.00 | ppl   148.76
# | epoch  54 |  3400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.96 | ppl   142.74
# | epoch  54 |  3600/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.99 | ppl   147.17
# | epoch  54 |  3800/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.95 | ppl   140.63
# | epoch  54 |  4000/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.94 | ppl   140.20
# | epoch  54 |  4200/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.93 | ppl   137.80
# | epoch  54 |  4400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.81 | ppl   122.92
# | epoch  54 |  4600/19523 batches | lr 0.33 | ms/batch  6.74 | loss  5.04 | ppl   154.55
# | epoch  54 |  4800/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.78 | ppl   119.57
# | epoch  54 |  5000/19523 batches | lr 0.33 | ms/batch  6.64 | loss  5.12 | ppl   166.54
# | epoch  54 |  5200/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.95 | ppl   140.87
# | epoch  54 |  5400/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.90 | ppl   134.55
# | epoch  54 |  5600/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.99 | ppl   146.89
# | epoch  54 |  5800/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.92 | ppl   137.22
# | epoch  54 |  6000/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.91 | ppl   135.59
# | epoch  54 |  6200/19523 batches | lr 0.33 | ms/batch  6.72 | loss  5.12 | ppl   166.64
# | epoch  54 |  6400/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.90 | ppl   134.28
# | epoch  54 |  6600/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.93 | ppl   138.35
# | epoch  54 |  6800/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.03 | ppl   153.04
# | epoch  54 |  7000/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.99 | ppl   146.43
# | epoch  54 |  7200/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.02 | ppl   151.12
# | epoch  54 |  7400/19523 batches | lr 0.33 | ms/batch  6.65 | loss  5.02 | ppl   151.06
# | epoch  54 |  7600/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.88 | ppl   131.40
# | epoch  54 |  7800/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.96 | ppl   143.28
# | epoch  54 |  8000/19523 batches | lr 0.33 | ms/batch  6.63 | loss  5.06 | ppl   157.27
# | epoch  54 |  8200/19523 batches | lr 0.33 | ms/batch  6.60 | loss  4.91 | ppl   135.76
# | epoch  54 |  8400/19523 batches | lr 0.33 | ms/batch  6.73 | loss  4.89 | ppl   133.08
# | epoch  54 |  8600/19523 batches | lr 0.33 | ms/batch  6.65 | loss  4.71 | ppl   110.55
# | epoch  54 |  8800/19523 batches | lr 0.33 | ms/batch  6.76 | loss  5.05 | ppl   155.47
# | epoch  54 |  9000/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.93 | ppl   138.48
# | epoch  54 |  9200/19523 batches | lr 0.33 | ms/batch  6.69 | loss  5.05 | ppl   155.89
# | epoch  54 |  9400/19523 batches | lr 0.33 | ms/batch  6.75 | loss  5.08 | ppl   160.26
# | epoch  54 |  9600/19523 batches | lr 0.33 | ms/batch  6.73 | loss  5.05 | ppl   156.31
# | epoch  54 |  9800/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.10 | ppl   163.89
# | epoch  54 | 10000/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.89 | ppl   133.09
# | epoch  54 | 10200/19523 batches | lr 0.33 | ms/batch  6.73 | loss  5.00 | ppl   147.89
# | epoch  54 | 10400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.00 | ppl   149.16
# | epoch  54 | 10600/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.87 | ppl   130.69
# | epoch  54 | 10800/19523 batches | lr 0.33 | ms/batch  6.79 | loss  4.91 | ppl   136.21
# | epoch  54 | 11000/19523 batches | lr 0.33 | ms/batch  6.68 | loss  5.00 | ppl   148.25
# | epoch  54 | 11200/19523 batches | lr 0.33 | ms/batch  6.68 | loss  5.05 | ppl   156.28
# | epoch  54 | 11400/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.98 | ppl   145.18
# | epoch  54 | 11600/19523 batches | lr 0.33 | ms/batch  6.65 | loss  5.04 | ppl   153.78
# | epoch  54 | 11800/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.81 | ppl   122.53
# | epoch  54 | 12000/19523 batches | lr 0.33 | ms/batch  6.66 | loss  4.85 | ppl   127.64
# | epoch  54 | 12200/19523 batches | lr 0.33 | ms/batch  6.73 | loss  4.99 | ppl   146.53
# | epoch  54 | 12400/19523 batches | lr 0.33 | ms/batch  6.63 | loss  4.97 | ppl   144.10
# | epoch  54 | 12600/19523 batches | lr 0.33 | ms/batch  6.70 | loss  5.12 | ppl   167.88
# | epoch  54 | 12800/19523 batches | lr 0.33 | ms/batch  6.66 | loss  5.01 | ppl   150.55
# | epoch  54 | 13000/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.99 | ppl   147.18
# | epoch  54 | 13200/19523 batches | lr 0.33 | ms/batch  6.62 | loss  5.02 | ppl   150.80
# | epoch  54 | 13400/19523 batches | lr 0.33 | ms/batch  6.69 | loss  5.02 | ppl   150.92
# | epoch  54 | 13600/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.93 | ppl   138.19
# | epoch  54 | 13800/19523 batches | lr 0.33 | ms/batch  6.63 | loss  4.94 | ppl   140.23
# | epoch  54 | 14000/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.91 | ppl   135.10
# | epoch  54 | 14200/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.93 | ppl   138.95
# | epoch  54 | 14400/19523 batches | lr 0.33 | ms/batch  6.66 | loss  5.01 | ppl   149.19
# | epoch  54 | 14600/19523 batches | lr 0.33 | ms/batch  6.72 | loss  4.86 | ppl   129.01
# | epoch  54 | 14800/19523 batches | lr 0.33 | ms/batch  6.64 | loss  4.84 | ppl   126.47
# | epoch  54 | 15000/19523 batches | lr 0.33 | ms/batch  6.71 | loss  4.88 | ppl   131.70
# | epoch  54 | 15200/19523 batches | lr 0.33 | ms/batch  6.74 | loss  4.92 | ppl   136.64
# | epoch  54 | 15400/19523 batches | lr 0.33 | ms/batch  6.64 | loss  4.82 | ppl   123.50
# | epoch  54 | 15600/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.90 | ppl   134.30
# | epoch  54 | 15800/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.90 | ppl   134.62
# | epoch  54 | 16000/19523 batches | lr 0.33 | ms/batch  6.67 | loss  4.98 | ppl   145.93
# | epoch  54 | 16200/19523 batches | lr 0.33 | ms/batch  6.65 | loss  4.94 | ppl   139.57
# | epoch  54 | 16400/19523 batches | lr 0.33 | ms/batch  6.68 | loss  4.83 | ppl   125.79
# | epoch  54 | 16600/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.99 | ppl   146.26
# | epoch  54 | 16800/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.79 | ppl   120.21
# | epoch  54 | 17000/19523 batches | lr 0.33 | ms/batch  6.64 | loss  5.12 | ppl   167.68
# | epoch  54 | 17200/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.89 | ppl   133.47
# | epoch  54 | 17400/19523 batches | lr 0.33 | ms/batch  6.68 | loss  5.02 | ppl   151.18
# | epoch  54 | 17600/19523 batches | lr 0.33 | ms/batch  6.66 | loss  4.85 | ppl   128.10
# | epoch  54 | 17800/19523 batches | lr 0.33 | ms/batch  6.78 | loss  5.09 | ppl   162.52
# | epoch  54 | 18000/19523 batches | lr 0.33 | ms/batch  6.70 | loss  4.92 | ppl   137.01
# | epoch  54 | 18200/19523 batches | lr 0.33 | ms/batch  6.73 | loss  5.01 | ppl   149.50
# | epoch  54 | 18400/19523 batches | lr 0.33 | ms/batch  6.71 | loss  5.04 | ppl   153.86
# | epoch  54 | 18600/19523 batches | lr 0.33 | ms/batch  6.66 | loss  4.94 | ppl   140.34
# | epoch  54 | 18800/19523 batches | lr 0.33 | ms/batch  6.66 | loss  4.85 | ppl   127.29
# | epoch  54 | 19000/19523 batches | lr 0.33 | ms/batch  6.69 | loss  4.99 | ppl   146.61
# | epoch  54 | 19200/19523 batches | lr 0.33 | ms/batch  6.63 | loss  4.89 | ppl   133.35
# | epoch  54 | 19400/19523 batches | lr 0.33 | ms/batch  6.77 | loss  4.91 | ppl   135.22
# -----------------------------------------------------------------------------------------
# | end of epoch  54 |
19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.05 | ppl   155.33
# | epoch  99 |  6200/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.22 | ppl   185.47
# | epoch  99 |  6400/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.07 | ppl   159.54
# | epoch  99 |  6600/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.08 | ppl   160.18
# | epoch  99 |  6800/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.19 | ppl   178.95
# | epoch  99 |  7000/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.16 | ppl   173.40
# | epoch  99 |  7200/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.14 | ppl   170.32
# | epoch  99 |  7400/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.15 | ppl   172.13
# | epoch  99 |  7600/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.05 | ppl   156.48
# | epoch  99 |  7800/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.08 | ppl   160.29
# | epoch  99 |  8000/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.17 | ppl   175.84
# | epoch  99 |  8200/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.05 | ppl   156.80
# | epoch  99 |  8400/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.06 | ppl   157.27
# | epoch  99 |  8600/19523 batches | lr 0.03 | ms/batch  6.61 | loss  4.90 | ppl   133.94
# | epoch  99 |  8800/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.15 | ppl   172.96
# | epoch  99 |  9000/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.10 | ppl   164.65
# | epoch  99 |  9200/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.21 | ppl   183.79
# | epoch  99 |  9400/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.24 | ppl   189.30
# | epoch  99 |  9600/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.24 | ppl   188.38
# | epoch  99 |  9800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.26 | ppl   192.43
# | epoch  99 | 10000/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.03 | ppl   152.52
# | epoch  99 | 10200/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.14 | ppl   171.15
# | epoch  99 | 10400/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.16 | ppl   174.13
# | epoch  99 | 10600/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.04 | ppl   154.89
# | epoch  99 | 10800/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.06 | ppl   156.82
# | epoch  99 | 11000/19523 batches | lr 0.03 | ms/batch  6.72 | loss  5.09 | ppl   162.47
# | epoch  99 | 11200/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.22 | ppl   184.17
# | epoch  99 | 11400/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.14 | ppl   170.74
# | epoch  99 | 11600/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.17 | ppl   175.16
# | epoch  99 | 11800/19523 batches | lr 0.03 | ms/batch  6.67 | loss  4.96 | ppl   142.50
# | epoch  99 | 12000/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.03 | ppl   152.30
# | epoch  99 | 12200/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.12 | ppl   167.69
# | epoch  99 | 12400/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.11 | ppl   165.63
# | epoch  99 | 12600/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.26 | ppl   191.71
# | epoch  99 | 12800/19523 batches | lr 0.03 | ms/batch  6.60 | loss  5.15 | ppl   173.13
# | epoch  99 | 13000/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.15 | ppl   172.06
# | epoch  99 | 13200/19523 batches | lr 0.03 | ms/batch  6.76 | loss  5.16 | ppl   174.71
# | epoch  99 | 13400/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.15 | ppl   173.01
# | epoch  99 | 13600/19523 batches | lr 0.03 | ms/batch  6.72 | loss  5.03 | ppl   152.42
# | epoch  99 | 13800/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.10 | ppl   164.06
# | epoch  99 | 14000/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.04 | ppl   153.85
# | epoch  99 | 14200/19523 batches | lr 0.03 | ms/batch  6.71 | loss  5.06 | ppl   157.29
# | epoch  99 | 14400/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.18 | ppl   177.96
# | epoch  99 | 14600/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.03 | ppl   152.26
# | epoch  99 | 14800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  4.99 | ppl   147.49
# | epoch  99 | 15000/19523 batches | lr 0.03 | ms/batch  6.72 | loss  5.02 | ppl   151.71
# | epoch  99 | 15200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.09 | ppl   161.88
# | epoch  99 | 15400/19523 batches | lr 0.03 | ms/batch  6.66 | loss  4.96 | ppl   142.83
# | epoch  99 | 15600/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.08 | ppl   161.12
# | epoch  99 | 15800/19523 batches | lr 0.03 | ms/batch  6.71 | loss  5.12 | ppl   167.32
# | epoch  99 | 16000/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.17 | ppl   175.66
# | epoch  99 | 16200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.10 | ppl   164.25
# | epoch  99 | 16400/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.01 | ppl   150.57
# | epoch  99 | 16600/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.12 | ppl   167.95
# | epoch  99 | 16800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  4.92 | ppl   136.82
# | epoch  99 | 17000/19523 batches | lr 0.03 | ms/batch  6.70 | loss  5.27 | ppl   194.36
# | epoch  99 | 17200/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.06 | ppl   157.06
# | epoch  99 | 17400/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.18 | ppl   176.99
# | epoch  99 | 17600/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.03 | ppl   153.47
# | epoch  99 | 17800/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.23 | ppl   186.40
# | epoch  99 | 18000/19523 batches | lr 0.03 | ms/batch  6.60 | loss  5.12 | ppl   167.19
# | epoch  99 | 18200/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.18 | ppl   176.96
# | epoch  99 | 18400/19523 batches | lr 0.03 | ms/batch  6.60 | loss  5.20 | ppl   182.05
# | epoch  99 | 18600/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.15 | ppl   171.96
# | epoch  99 | 18800/19523 batches | lr 0.03 | ms/batch  6.62 | loss  4.98 | ppl   145.83
# | epoch  99 | 19000/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.17 | ppl   175.10
# | epoch  99 | 19200/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.09 | ppl   163.15
# | epoch  99 | 19400/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.06 | ppl   158.16
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time: 133.79s | valid loss  5.56 | valid ppl   259.06
# -----------------------------------------------------------------------------------------
# | epoch 100 |   200/19523 batches | lr 0.03 | ms/batch  6.71 | loss  5.23 | ppl   186.32
# | epoch 100 |   400/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.20 | ppl   181.75
# | epoch 100 |   600/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.13 | ppl   168.47
# | epoch 100 |   800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.12 | ppl   167.93
# | epoch 100 |  1000/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.13 | ppl   169.23
# | epoch 100 |  1200/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.12 | ppl   167.51
# | epoch 100 |  1400/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.19 | ppl   179.74
# | epoch 100 |  1600/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.16 | ppl   173.49
# | epoch 100 |  1800/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.10 | ppl   164.21
# | epoch 100 |  2000/19523 batches | lr 0.03 | ms/batch  6.71 | loss  5.10 | ppl   163.36
# | epoch 100 |  2200/19523 batches | lr 0.03 | ms/batch  6.73 | loss  5.18 | ppl   178.52
# | epoch 100 |  2400/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.18 | ppl   177.81
# | epoch 100 |  2600/19523 batches | lr 0.03 | ms/batch  6.65 | loss  4.85 | ppl   128.32
# | epoch 100 |  2800/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.20 | ppl   181.13
# | epoch 100 |  3000/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.03 | ppl   152.60
# | epoch 100 |  3200/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.15 | ppl   171.70
# | epoch 100 |  3400/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.10 | ppl   163.66
# | epoch 100 |  3600/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.13 | ppl   169.76
# | epoch 100 |  3800/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.07 | ppl   159.65
# | epoch 100 |  4000/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.07 | ppl   159.57
# | epoch 100 |  4200/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.08 | ppl   160.44
# | epoch 100 |  4400/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.00 | ppl   148.08
# | epoch 100 |  4600/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.17 | ppl   175.33
# | epoch 100 |  4800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  4.95 | ppl   141.81
# | epoch 100 |  5000/19523 batches | lr 0.03 | ms/batch  6.60 | loss  5.24 | ppl   189.57
# | epoch 100 |  5200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.10 | ppl   164.04
# | epoch 100 |  5400/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.07 | ppl   159.47
# | epoch 100 |  5600/19523 batches | lr 0.03 | ms/batch  6.83 | loss  5.21 | ppl   182.62
# | epoch 100 |  5800/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.04 | ppl   154.99
# | epoch 100 |  6000/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.04 | ppl   154.52
# | epoch 100 |  6200/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.21 | ppl   183.41
# | epoch 100 |  6400/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.07 | ppl   159.39
# | epoch 100 |  6600/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.07 | ppl   159.46
# | epoch 100 |  6800/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.19 | ppl   178.83
# | epoch 100 |  7000/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.15 | ppl   172.92
# | epoch 100 |  7200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.15 | ppl   171.76
# | epoch 100 |  7400/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.15 | ppl   172.11
# | epoch 100 |  7600/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.06 | ppl   157.82
# | epoch 100 |  7800/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.08 | ppl   160.42
# | epoch 100 |  8000/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.18 | ppl   177.22
# | epoch 100 |  8200/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.04 | ppl   154.43
# | epoch 100 |  8400/19523 batches | lr 0.03 | ms/batch  6.60 | loss  5.06 | ppl   156.92
# | epoch 100 |  8600/19523 batches | lr 0.03 | ms/batch  6.62 | loss  4.89 | ppl   132.66
# | epoch 100 |  8800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.16 | ppl   174.76
# | epoch 100 |  9000/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.11 | ppl   165.55
# | epoch 100 |  9200/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.22 | ppl   185.66
# | epoch 100 |  9400/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.25 | ppl   189.88
# | epoch 100 |  9600/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.23 | ppl   186.73
# | epoch 100 |  9800/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.25 | ppl   191.27
# | epoch 100 | 10000/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.03 | ppl   153.55
# | epoch 100 | 10200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.15 | ppl   172.24
# | epoch 100 | 10400/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.16 | ppl   173.44
# | epoch 100 | 10600/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.05 | ppl   155.61
# | epoch 100 | 10800/19523 batches | lr 0.03 | ms/batch  6.73 | loss  5.05 | ppl   156.22
# | epoch 100 | 11000/19523 batches | lr 0.03 | ms/batch  6.70 | loss  5.10 | ppl   163.31
# | epoch 100 | 11200/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.21 | ppl   183.81
# | epoch 100 | 11400/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.14 | ppl   171.08
# | epoch 100 | 11600/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.18 | ppl   177.18
# | epoch 100 | 11800/19523 batches | lr 0.03 | ms/batch  6.63 | loss  4.97 | ppl   144.23
# | epoch 100 | 12000/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.02 | ppl   151.79
# | epoch 100 | 12200/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.12 | ppl   167.87
# | epoch 100 | 12400/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.12 | ppl   166.74
# | epoch 100 | 12600/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.27 | ppl   193.62
# | epoch 100 | 12800/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.16 | ppl   173.89
# | epoch 100 | 13000/19523 batches | lr 0.03 | ms/batch  6.70 | loss  5.15 | ppl   172.98
# | epoch 100 | 13200/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.17 | ppl   175.76
# | epoch 100 | 13400/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.15 | ppl   172.55
# | epoch 100 | 13600/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.03 | ppl   153.12
# | epoch 100 | 13800/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.10 | ppl   163.56
# | epoch 100 | 14000/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.04 | ppl   153.94
# | epoch 100 | 14200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.06 | ppl   158.11
# | epoch 100 | 14400/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.18 | ppl   177.80
# | epoch 100 | 14600/19523 batches | lr 0.03 | ms/batch  6.78 | loss  5.03 | ppl   152.81
# | epoch 100 | 14800/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.01 | ppl   150.21
# | epoch 100 | 15000/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.04 | ppl   154.21
# | epoch 100 | 15200/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.09 | ppl   161.72
# | epoch 100 | 15400/19523 batches | lr 0.03 | ms/batch  6.62 | loss  4.97 | ppl   144.18
# | epoch 100 | 15600/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.08 | ppl   161.58
# | epoch 100 | 15800/19523 batches | lr 0.03 | ms/batch  6.71 | loss  5.12 | ppl   167.81
# | epoch 100 | 16000/19523 batches | lr 0.03 | ms/batch  6.62 | loss  5.18 | ppl   177.89
# | epoch 100 | 16200/19523 batches | lr 0.03 | ms/batch  6.63 | loss  5.10 | ppl   164.05
# | epoch 100 | 16400/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.01 | ppl   150.44
# | epoch 100 | 16600/19523 batches | lr 0.03 | ms/batch  6.67 | loss  5.13 | ppl   168.27
# | epoch 100 | 16800/19523 batches | lr 0.03 | ms/batch  6.61 | loss  4.91 | ppl   135.68
# | epoch 100 | 17000/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.27 | ppl   195.36
# | epoch 100 | 17200/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.06 | ppl   156.99
# | epoch 100 | 17400/19523 batches | lr 0.03 | ms/batch  6.61 | loss  5.17 | ppl   176.46
# | epoch 100 | 17600/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.03 | ppl   152.48
# | epoch 100 | 17800/19523 batches | lr 0.03 | ms/batch  6.65 | loss  5.23 | ppl   187.61
# | epoch 100 | 18000/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.14 | ppl   170.66
# | epoch 100 | 18200/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.16 | ppl   174.50
# | epoch 100 | 18400/19523 batches | lr 0.03 | ms/batch  6.66 | loss  5.22 | ppl   184.09
# | epoch 100 | 18600/19523 batches | lr 0.03 | ms/batch  6.64 | loss  5.15 | ppl   173.09
# | epoch 100 | 18800/19523 batches | lr 0.03 | ms/batch  6.63 | loss  4.99 | ppl   147.20
# | epoch 100 | 19000/19523 batches | lr 0.03 | ms/batch  6.68 | loss  5.18 | ppl   177.45
# | epoch 100 | 19200/19523 batches | lr 0.03 | ms/batch  6.70 | loss  5.09 | ppl   162.81
# | epoch 100 | 19400/19523 batches | lr 0.03 | ms/batch  6.69 | loss  5.07 | ppl   158.86
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time: 133.79s | valid loss  5.56 | valid ppl   258.85
# -----------------------------------------------------------------------------------------

# %% [markdown]
# Evaluate the model with the test dataset
# -------------------------------------
#
# Apply the best model to check the result with the test dataset.

# %%
test_loss = evaluate(best_model, test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  5.48 | test ppl   239.27
# =========================================================================================

# %% [markdown]
# **Save Model**

# %%
cd /content/drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# MyDrive

# %%
import numpy as np
import os
np.savetxt("MyDrive/foo.txt", np.zeros(4))

# %%
outdir = "MyDrive" 

# approach 1: save model weights
"""
# load as: 
# model.load_state_dict(torch.load('model_weights.pth'))
# model.eval()
"""
torch.save(model.state_dict(), outdir + os.sep + 'model_weights.pth')

# approach 2: save model (class) entirely (uses pickle)
"""
# load as: model = torch.load('model.pth')
"""
torch.save(model, outdir + os.sep + 'model.pth')

# %%
# !ls
# Out:
# MyDrive
